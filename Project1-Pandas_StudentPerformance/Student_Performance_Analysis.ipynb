# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Maths.csv')

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %% [markdown]
# # find optimum number of study time hours

# %%
studytime_with_grades = df[['studytime','G1','G2','G3']]

# %%
studytime_with_grades = studytime_with_grades.groupby(['studytime']).mean()
studytime_with_grades['average'] = studytime_with_grades[['G1','G2','G3']].mean(axis=1)
studytime_with_grades
# Out:
#                   G1         G2         G3    average
# studytime
# 1          10.438095  10.276190  10.047619  10.253968
# 2          10.651515  10.505051  10.171717  10.442761
# 3          12.046154  11.507692  11.400000  11.651282
# 4          11.888889  12.037037  11.259259  11.728395

# %%
# Here, I analyzed two variables 'studytime' and 'average' (average of grades of three periods) to see if studytime is
#a considerable factor in deciding the grades of the student. But, the table above shows that there is not a strong correlation
# between studytime and avarage of the grades as the average grades are in the same range.

# %%
final_df.columns
# Out:
# Index(['studytime', 'G1', 'G2', 'G3', 'average'], dtype='object')

# %%
# Get average of G1, G2, G3
average = list(final_df[['G1','G2','G3']].mean(axis=1))
average
# Out:
# [5.666666666666667,
#  5.333333333333333,
#  8.333333333333334,
#  14.666666666666666,
#  8.666666666666666,
#  15.0,
#  11.666666666666666,
#  5.666666666666667,
#  17.666666666666668,
#  14.666666666666666,
#  9.0,
#  11.333333333333334,
#  14.0,
#  10.333333333333334,
#  15.333333333333334,
#  14.0,
#  13.666666666666666,
#  9.333333333333334,
#  5.333333333333333,
#  9.333333333333334,
#  14.0,
#  14.0,
#  15.333333333333334,
#  12.666666666666666,
#  9.0,
#  7.666666666666667,
#  11.666666666666666,
#  15.333333333333334,
#  11.0,
#  11.0,
#  10.666666666666666,
#  16.666666666666668,
#  16.333333333333332,
#  10.0,
#  13.666666666666666,
#  7.0,
#  16.333333333333332,
#  15.333333333333334,
#  11.666666666666666,
#  13.333333333333334,
#  9.333333333333334,
#  12.0,
#  18.333333333333332,
#  9.0,
#  9.666666666666666,
#  7.333333333333333,
#  11.333333333333334,
#  19.333333333333332,
#  14.666666666666666,
#  7.0,
#  12.666666666666666,
#  12.333333333333334,
# ...

# %%
studytime = list(final_df["studytime"])
studytime
# Out:
# [2,
#  2,
#  2,
#  3,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  3,
#  1,
#  2,
#  3,
#  1,
#  3,
#  2,
#  1,
#  1,
#  2,
#  1,
#  2,
#  2,
#  3,
#  1,
#  1,
#  1,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  1,
#  1,
#  3,
#  3,
#  3,
#  1,
#  2,
#  1,
#  2,
#  1,
#  2,
#  2,
#  2,
#  4,
#  2,
#  2,
#  2,
#  2,
#  1,
#  1,
#  1,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  1,
#  2,
#  3,
#  2,
#  2,
#  4,
#  4,
#  2,
#  4,
#  4,
#  4,
#  2,
#  1,
#  2,
#  2,
#  4,
#  4,
#  1,
#  2,
#  1,
#  3,
#  2,
#  2,
#  2,
#  2,
#  2,
#  3,
#  2,
#  2,
#  3,
#  1,
#  2,
#  2,
#  4,
#  4,
#  1,
#  2,
#  1,
#  3,
#  1,
#  3,
#  1,
#  2,
#  2,
#  4,
#  4,
#  3,
#  4,
#  3,
#  1,
#  3,
#  2,
#  1,
#  2,
#  2,
#  2,
#  1,
#  2,
#  1,
#  2,
#  4,
#  2,
#  1,
#  2,
#  1,
#  2,
#  2,
#  1,
#  1,
#  3,
#  1,
#  1,
#  1,
#  2,
#  3,
#  2,
#  1,
#  2,
#  1,
#  4,
#  1,
#  3,
#  1,
#  1,
#  2,
#  2,
#  2,
#  1,
#  1,
#  1,
#  1,
#  3,
#  1,
#  1,
#  2,
#  1,
#  1,
#  1,
#  2,
#  1,
#  2,
#  1,
#  1,
#  2,
#  1,
# ...

# %%
plt.bar(studytime,average)
# Out:
# <BarContainer object of 395 artists>
